# %% [markdown]
# # Seagrass Carbon Stock Model
#
# <!-- vscode-markdown-toc -->
# - [Seagrass Carbon Stock Model](#seagrass-carbon-stock-model)
#   - [!Important! The list of European seagrasses](#important-the-list-of-european-seagrasses)
#   - [Running the workflow in NaaVRE](#running-the-workflow-in-naavre)
#     - [Run the workflow from parameter input GUI](#run-the-workflow-from-parameter-input-gui)
#     - [Run the workflow from excel file input GUI](#run-the-workflow-from-excel-file-input-gui)
#   - [Retrieve the output data](#retrieve-the-output-data)
#
# <!-- vscode-markdown-toc-config
# 	numbering=false
# 	autoSave=true
# 	/vscode-markdown-toc-config -->
# <!-- /vscode-markdown-toc -->
#
# ## <a name='ImportantThelistofEuropeanseagrasses'></a>**!Important!** The list of European seagrasses
#
# * Cymodocea nodosa
# * Halophila stipulacea
# * Posidonia oceanica
# * Zostera marina
# * Zostera noltei
# * Zostera marina and Cymodocea nodosa
# * Zostera marina and Zostera noltei
#
# ## <a name='RunningtheworkflowinNaaVRE'></a>Running the workflow in NaaVRE
#
# To run the workflow, you need to open the virtual lab in NaaVRE. If you are not in NaaVRE, click the link to the virtual lab (https://beta.naavre.net/vreapp/vl/blue-carbon) and press `Launch my instance` button.
#
# ### <a name='RuntheworkflowfromparameterinputGUI'></a>Run the workflow from **parameter** input GUI
#
# |      | Step | Action |
# | ---- | ---- | ------ |
# | 1    | Open the workflow file | open [run model from parameter input GUI](./workflows/run_model_from_GUI_input.naavrewf) |
# | 2    | Start workflow         | ![img_tutorial_01-Run_workflow.png](documentation/images/img_tutorial_01-Run_workflow.png "Start workflow") |
# | 3    | Set parameter values   | |
# | 3.1  | Fill values by default | ![img_tutorial_02-Use_default_parameters.png](documentation/images/img_tutorial_02-Use_default_parameters.png "Default parameter values")
# | 3.2  | Change values in the **parameter window** | ![img_tutorial_02a-Set_default_parameters.png](documentation/images/img_tutorial_02a-Set_default_parameters.png "Set parameter values") |
# | 4    | Execute workflow       | ![img_tutorial_03-Exec_workflow.png](documentation/images/img_tutorial_03-Exec_workflow.png "Execute workflow") |
# | 5    | Check the progress     | ![img_tutorial_04-Progress.png](documentation/images/img_tutorial_04-Progress.png "Check the progress") |
# > Option: the details of the progress can be found by press `Show in workflow engine` or https://staging.demo.naavre.net/argowf/workflows
#
# ### <a name='RuntheworkflowfromexcelfileinputGUI'></a>Run the workflow from **excel file** input GUI
#
# **!Important!** Use template excel file to set input parameters. The `Template-Seagrass_site_data.xlsx` can be found in the directory or from [github](https://github.com/QCDIS/Seagrass_carbon_stock_model/blob/522485aca0b1917022c5b4166053e3860a98e679/Template-Seagrass_site_data.xlsx)
#
# |      | Step | Action |
# | ---- | ---- | ------ |
# | 1    | Open the workflow file | open [run model excel file input GUI](./workflows/run_model_from_Excel_upload.naavrewf) |
# | 1.a  | Download template file       | ![img_tutorial_05-Template_file.png](documentation/images/img_tutorial_05-Template_file.png "Template file") |
# | 1.b  | Upload file to `data` folder | ![img_tutorial_06a-Upload_file.png](documentation/images/img_tutorial_06a-Upload_file.png "Upload") ==> ![img_tutorial_06b-Upload_file.png](documentation/images/img_tutorial_06b-Upload_file.png "data folder") |
# | 1.c  | Click `Git public` back      | ![img_tutorial_06c-Back_to_root.png](documentation/images/img_tutorial_06c-Back_to_root.png "Back") |
# | 2    | Start workflow         | ![img_tutorial_01-Run_workflow.png](documentation/images/img_tutorial_01-Run_workflow.png "Start workflow") |
# | 3    | Set parameter values   | |
# | 3.1  | Fill values by default | ![img_tutorial_02-Use_default_parameters.png](documentation/images/img_tutorial_02-Use_default_parameters.png "Default parameter values")
# | 3.2  | Change values in the **parameter window** | ![img_tutorial_02b-Set_default_parameters.png](documentation/images/img_tutorial_02b-Set_default_parameters.png "Set parameter values") |
# | 4    | Execute workflow       | ![img_tutorial_03-Exec_workflow.png](documentation/images/img_tutorial_03-Exec_workflow.png "Execute workflow") |
# | 5    | Check the progress     | ![img_tutorial_04-Progress.png](documentation/images/img_tutorial_04-Progress.png "Check the progress") |
# > Option: the details of the progress can be found by press `Show in workflow engine` or https://staging.demo.naavre.net/argowf/workflows
#
# ## <a name='Retrievetheoutputdata'></a>Retrieve the output data
#
# In the `data` folder, you should see the result files from you workflow.
#
# You can download the file by doing right click, then press `download`.
#
# ![img_tutorial_07-Result.png](documentation/images/img_tutorial_07-Result.png "Result in data folder")

# %% [markdown]
# # Advanced use of workflow
#
# <!-- vscode-markdown-toc -->
# - [Advanced use of workflow](#advanced-use-of-workflow)
#   - [Inspecting the source code](#inspecting-the-source-code)
#   - [Adapting the workflow for your own needs](#adapting-the-workflow-for-your-own-needs)
#
# <!-- vscode-markdown-toc-config
# 	numbering=false
# 	autoSave=true
# 	/vscode-markdown-toc-config -->
# <!-- /vscode-markdown-toc -->
#
# ## <a name='Inspectingthesourcecode'></a>Inspecting the source code
# You can look at the source code available in this virtual lab: _[/codebase/FILENAME]()_.
#
# ## <a name='Adaptingtheworkflowforyourownneeds'></a>Adapting the workflow for your own needs
# You can adapt the workflow in NaaVRE to suit your own research objectives. To do this:
#
# 1) Create a fork of the git: https://github.com/QCDIS/Seagrass_carbon_stock_model/
#
# ![1_create_fork.png](documentation/images/1_create_fork.png)
#
# 2) On Github, create a fine grained personal access token for your repository: https://github.com/settings/personal-access-tokens/new . The permissions need to be set to _Read and Write access_ for _Contents_.
#
# ![2_fine_grained_personal_access_token_permissions.png](documentation/images/2_fine_grained_personal_access_token_permissions.png)
#
# 3) In the file browser, go to _Virtual Labs -> Seagrass carbon stock model -> My data_
#
# ![3_my_data.png](documentation/images/3_my_data.png)
#
# 4) Go to _Git_ in NaaVRE, press _Clone a repository_.
#
# ![4_clone_repository.png](documentation/images/4_clone_repository.png)
#
# 5) Enter the url of your forked repository.
#
# You a now free to change the virtual lab as necessary.
